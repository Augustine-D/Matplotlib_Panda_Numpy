# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load file
fifa =pd.read_csv('fifa_data.csv')
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %% [markdown]
# # Pie Chart

# %%
fifa.head(3)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# ...

# %%
fifa['Preferred Foot']
# Out:
# 0         Left
# 1        Right
# 2        Right
# 3        Right
# 4        Right
#          ...
# 18202    Right
# 18203    Right
# 18204    Right
# 18205    Right
# 18206    Right
# Name: Preferred Foot, Length: 18207, dtype: object

# %%
left = fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]
print(left)
print(right)
# Out:
# 4211
# 13948

# %%
plt.pie([left,right])
plt.show()

# %%
#adding labels
left = fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]
plt.pie([left,right], labels = labels)
plt.show()
labels=['Left Foot players','Right foot players']

# %%
# adding colors
left = fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]

labels=['Left Foot players','Right foot players']
colors=['Blue','red']
plt.pie([left,right], labels = labels, colors=colors)
plt.show()

# %%
#add percentage
plt.title('Preferred Foot Preferance of Fifa Players')
left = fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]

labels=['Left Foot players','Right foot players']
colors=['Blue','red']
plt.pie([left,right], labels = labels, colors=colors, autopct='%.4f %%')
plt.show()

# %% [markdown]
# # Pie Chart 2

# %%
fifa.head(2)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona  ...
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus  ...
#
#   Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 0      96.0    33.0           28.0           26.0      6.0        11.0
# 1      95.0    28.0           31.0           23.0      7.0        11.0
#
#    GKKicking  GKPositioning GKReflexes Release Clause
# 0       15.0           14.0        8.0        €226.5M
# 1       15.0           14.0       11.0        €127.1M
#
# ...

# %%
fifa.Weight
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object

# %%
#remove lbs to use integers for calculations

# %%
fifa.Weight = [int(x.strip('lbs')) if type(x) ==str else x for x in fifa.Weight]

# %%
fifa.Weight
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, Length: 18207, dtype: float64

# %%
light = fifa.loc[fifa.Weight < 125].count()[0]

light_medium =fifa.loc[(fifa.Weight >= 125) & (fifa.Weight <150)].count()[0]
light_medium =fifa.loc[(fifa.Weight >=150) & (fifa.Weight<175 )].count()[0]
medium =fifa.loc[(fifa.Weight >=150) & (fifa.Weight<175 )].count()[0]
medium_heavy =fifa.loc[(fifa.Weight >=175) & (fifa.Weight<200 )].count()[0]
heavy =fifa.loc[(fifa.Weight >=200)].count()[0]

# %%
#add percentage
plt.title('Preferred Foot Preferance of Fifa Players')

labels=['Left Foot players','heavy','heavy','heavy','heavy','heavy']
colors=['Blue','red']
plt.pie([light,light_medium,light_medium,medium,medium_heavy,heavy], labels = labels, colors=colors, autopct='%.4f %%')
plt.show()

# %%
#another way of plotting it

light = fifa.loc[fifa.Weight < 125].count()[0]

light_medium =fifa.loc[(fifa.Weight >= 125) & (fifa.Weight <150)].count()[0]
light_medium =fifa.loc[(fifa.Weight >=150) & (fifa.Weight<175 )].count()[0]
medium =fifa.loc[(fifa.Weight >=150) & (fifa.Weight<175 )].count()[0]
medium_heavy =fifa.loc[(fifa.Weight >=175) & (fifa.Weight<200 )].count()[0]
heavy =fifa.loc[(fifa.Weight >=200)].count()[0]

plt.title(' ')

labels=['Left Foot players','heavy','heavy','heavy','heavy','heavy']

colors=['Blue','red','green','black','yellow','grey']

weights = [light,light_medium,light_medium,medium,medium_heavy,heavy] 

plt.pie(weights, labels = labels, colors=colors, autopct='%.4f %%')

plt.show()

# %%
##another way of plotting it

light = fifa.loc[fifa.Weight < 125].count()[0]

light_medium =fifa.loc[(fifa.Weight >= 125) & (fifa.Weight <150)].count()[0]
light_medium =fifa.loc[(fifa.Weight >=150) & (fifa.Weight<175 )].count()[0]
medium =fifa.loc[(fifa.Weight >=150) & (fifa.Weight<175 )].count()[0]
medium_heavy =fifa.loc[(fifa.Weight >=175) & (fifa.Weight<200 )].count()[0]
heavy =fifa.loc[(fifa.Weight >=200)].count()[0]

plt.title(' ')

labels=['Left Foot players','heavy','heavy','heavy','heavy','heavy']

#colors=['Blue','red','green','black','yellow','grey']

#another way to change colors
'#plt.style.use('ggplot')

weights = [light,light_medium,light_medium,medium,medium_heavy,heavy] 

plt.pie(weights, labels = labels,  autopct='%.4f %%')

plt.show()

# %%
#spearate the distances
##another way of plotting it

light = fifa.loc[fifa.Weight < 125].count()[0]

light_medium =fifa.loc[(fifa.Weight >= 125) & (fifa.Weight <150)].count()[0]

medium =fifa.loc[(fifa.Weight >=150) & (fifa.Weight<175 )].count()[0]

medium_heavy =fifa.loc[(fifa.Weight >=175) & (fifa.Weight<200 )].count()[0]

heavy =fifa.loc[(fifa.Weight >=200)].count()[0]

plt.title('Weight distribution of fifa players \n\n')

#colors=['Blue','red','green','black','yellow','grey']

#another way to change colors
plt.style.use('ggplot')

weights = [light, light_medium, medium, medium_heavy, heavy] 

labels=['Under 125','125-150','150-175','175-200','Over 200']

explode=(.4,.2,.0,.0,.4)
plt.pie( weights, labels = labels,  autopct='%.2f %%', pctdistance=0.8, explode=explode)

plt.legend(bbox_to_anchor=(-0.35, .5), loc='upper left')
plt.show()

# %% [markdown]
# ## Box and whiskers chart

# %%
plt.style.use('default')
barcelona = fifa.loc[fifa.Club == 'FC Barcelona']['Overall']
madrid = fifa.loc[fifa.Club == 'Real Madrid']['Overall']
revs = fifa.loc[fifa.Club == 'New England Revolution']['Overall']
labels=['FC Barcelona \n', 'Real Madrid \n', 'New England Revolution']
plt.title('PROFESSIONAL SOCCER TEAM COMPARISONS \n')
plt.boxplot([barcelona, madrid,revs], labels=labels)
plt.ylabel('\n\n FIFA OVERALL RATING')
plt.show()

# %%
#changing box colors
plt.style.use('default')
barcelona = fifa.loc[fifa.Club == 'FC Barcelona']['Overall']
madrid = fifa.loc[fifa.Club == 'Real Madrid']['Overall']
revs = fifa.loc[fifa.Club == 'New England Revolution']['Overall']
labels=['FC Barcelona \n', 'Real Madrid \n', 'New England Revolution']
plt.title('PROFESSIONAL SOCCER TEAM COMPARISONS \n')

boxes = plt.boxplot([barcelona, madrid,revs], labels=labels, patch_artist=True)

for box in boxes['boxes']:
    #set edge color
    box.set(color='#4286f4', linewidth=2)
    
    #change fill color
    box.set(facecolor='#e0e0e0')

plt.ylabel('\n\n FIFA OVERALL RATING')
plt.show()
